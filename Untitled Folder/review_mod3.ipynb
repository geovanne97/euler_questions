# %%
#metodos importantes descrever data
#df.describe()
#value_counts()

#fazer com que o index seja o valor de uma coluna: df.index.name = 'coluna_a'

#scatter_plot, é usado para verificar a relação entre duas variaveis num gráfico cartesiano

#groupby,ele pega os valores iguais de uma coluna e cria uma nova tabela com a media desses valores

# %%
import pandas as pd
import numpy as np

path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length ...   \
# 0  convertible          rwd           front        88.6  0.811148 ...
# 1  convertible          rwd           front        88.6  0.811148 ...
# 2    hatchback          rwd           front        94.5  0.822681 ...
# 3        sedan          fwd           front        99.8  0.848630 ...
# 4        sedan          4wd           front        99.4  0.848630 ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# list the data types for each column
print(df["peak-rpm"].dtypes)
# Out:
# float64

# %%
#vamos achar a correlaçao de algumas colunas
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
#correlaçao linear positiva
sns.regplot(x="engine-size", y="price",data=df)
#proximo metodo estipula o limite min(botton) e max(top) do eixo y
plt.ylim(0,)
# Out:
# /home/geovanne/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0, 55988.96893647209)

# %%
#agora se eu pegar as mesmas colunas do grafico passado e tirar a correlaçao delas vai ser aproximado de 1, 
#pois é uma correlaçao positiva, a corr = 0.87
#essa correlaçao que dizer que a coluna engine-size é um bom preditor de price
df[["engine-size","price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
#agora uma correlação negativa
sns.regplot(x="highway-mpg", y="price", data=df)
# Out:
# /home/geovanne/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#observando o gráfico acima já se sabe que a correlação é negativa, logo se o highway-mpg aumenta o preço desce
#o highway é um bom preditor de price tbm
df[["highway-mpg","price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
#agora vamos ver uma correlação fraca, a linha do gráfico é quase horizontal
sns.regplot(x="peak-rpm", y="price", data=df)
# Out:
# /home/geovanne/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#o resultado de corr() é quase 0, logo a coluna peak-rpm n é boa pra predizer o price, entao ela poderia ser deletad
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
#variaveis categoricas, se os dados nao sao numericos, podemos visualizar como ela afeta o price usando o box-plot
#a coluna categorica body-style nao seria um bom preditor para price, o box-plot dependendo do estilo do valor varia
#muito o preço, além dos preços por estilo de carro nao se diferenciarem tanto
sns.boxplot(x="body-style", y="price", data=df)

# %%
#nesse exemplo a coluna engine-location seria um bom preditor de price, os preços de rear e front sao bem
#distintos
sns.boxplot(x="engine-location", y="price", data=df)

# %%
# drive-wheels could potentially be a predictor of price.
sns.boxplot(x="drive-wheels", y="price", data=df)

# %%
#The describe function automatically computes basic statistics for all continuous variables. 
#Any NaN values are automatically skipped in these statistics.
#os dados que o describe() oferece:the count of that variable, the mean,the standard deviation (std)
#the minimum value,the IQR (Interquartile Range: 25%, 50% and 75%),the maximum value
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
#o modo default do describe nao coloca as colunas categoricas'objects'
#vamos incluir elas
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
#ele mostra os valores que tem na coluna e qnt ele se repetiu nessa coluna
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
#vamos tranformar pra dataframe o dado anterior
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
#agora vamos criar um novo dataframe(drive_wheels_counts) com os values da coluna drive-wheels e depoir renomear essa coluna
#para value_counts
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'},inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
#renomear o index
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels','body-style','price']]

df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
# it seems rear-wheel drive vehicles are, on average, the most expensive
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
#agora vamos agrupar com duas colunas
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
#ele vai pegar a combinaçao da coluna 1 com a coluna 2 e calcular o preço medio da combinaçao dessas
#duas caracteristicas
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df_gptest.head()
# Out:
#   drive-wheels   body-style    price
# 0          rwd  convertible  13495.0
# 1          rwd  convertible  16500.0
# 2          rwd    hatchback  16500.0
# 3          fwd        sedan  13950.0
# 4          4wd        sedan  17450.0

# %%
#o metodo pivot ele monta uma tabela com valores de coluna 1 no index e valores de coluna 2 no eixo x
#e a intersecção dos valores terao resultados de uma terceira coluna, que no caso é price
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
#agora vamos achar a media do price baseado na coluna bodystyle
df_gptest2 = df[['body-style','price']]
df_group_one = df_gptest2.groupby(['body-style'],as_index=False).mean()
df_group_one
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
#use the grouped results
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names, qnd eu crio a tabela pivot eu ja defino o index e a coluna, só pegar elas agora
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
#correlação e causa sao conceitos bem diferentes
#a correlação nao explica a causa
#The Pearson Correlation measures the linear dependence between two variables X and Y.
#The resulting coefficient is a value between -1 and 1
#we can calculate the Pearson Correlation of the of the 'int64' or 'float64' variables, pelo metodo df.corr()

#p_value
# P-value is the probability value that the correlation between these two variables is statistically significant.
#o quao confiavel a correlçao é

#p-value is  <  0.001: we say there is strong evidence that the correlation is significant.
#the p-value is  <  0.05: there is moderate evidence that the correlation is significant.
#the p-value is  <  0.1: there is weak evidence that the correlation is significant.
#the p-value is  >  0.1: there is no evidence that the correlation is significant.

#We can obtain this information using "stats" module in the "scipy" library.

from scipy import stats

# %%
#Let's calculate the Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'
pearson_coef,p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value) 
#The Pearson Correlation Coefficient is 0.5846418222655081  with a P-value of P = 8.076488270732955e-20
#p-value is  <  0.001, the correlation between wheel-base and price is statistically significant, 
#although the linear relationship isn't extremely strong (0.585)
# Out:
# The Pearson Correlation Coefficient is 0.5846418222655081  with a P-value of P = 8.076488270732955e-20

# %%
#Let's calculate the Pearson Correlation Coefficient and P-value of 'horsepower' and 'price'.
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)  
#p-value is  <  0.001, the correlation between horsepower and price is statistically significant, 
#and the linear relationship is quite strong (~0.809, close to 1)
# Out:
# The Pearson Correlation Coefficient is 0.8095745670036559  with a P-value of P =  6.36905742825998e-48

# %%
grouped_test2=df_gptest[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped_test2.head(2)
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 136          4wd   7603.0

# %%
df_gptest
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# 5            fwd        sedan  15250.0
# 6            fwd        sedan  17710.0
# 7            fwd        wagon  18920.0
# 8            fwd        sedan  23875.0
# 9            rwd        sedan  16430.0
# 10           rwd        sedan  16925.0
# 11           rwd        sedan  20970.0
# 12           rwd        sedan  21105.0
# 13           rwd        sedan  24565.0
# 14           rwd        sedan  30760.0
# 15           rwd        sedan  41315.0
# 16           rwd        sedan  36880.0
# 17           fwd    hatchback   5151.0
# 18           fwd    hatchback   6295.0
# 19           fwd        sedan   6575.0
# 20           fwd    hatchback   5572.0
# 21           fwd    hatchback   6377.0
# 22           fwd    hatchback   7957.0
# ...

# %%
grouped_test2.get_group('4wd')['price']
#ele me mostra o index do primeiro e o valor do price
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
# ANOVA, é utilizado pra saber se tem mt diferença de média entre 2 ou mais grupos
#ela me retorna 2 valores
#F,Anova assume que a media de tds os grupos sao a mesma, e calcula o quanto a media atual se desvia da hipotese
# um F grande assume que tem uma grande diferença entre as medias
#segundo dado que a anova da é o p_value
#se a coluna que estamos analizando for altamente correlacionada com o price, se espera que o F seja considerável 
# o p_value bem pequeno

f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val) 
#large F test score showing a strong correlation and a P value of almost 0 implying almost 
#certain statistical significance.
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('rwd')['price'])  
   
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('fwd')['price'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666
